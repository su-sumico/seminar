# %% [markdown]
# <a href="https://colab.research.google.com/github/su-sumico/seminar/blob/main/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# YOLOv8 物体検出

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd ./drive/MyDrive/yolo/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: './drive/MyDrive/yolo/'
# /content/drive/MyDrive/yolo/ultralytics

# %%
# !git clone https://github.com/ultralytics/ultralytics
# %cd ultralytics
# Out:
# fatal: destination path 'ultralytics' already exists and is not an empty directory.
# /content/drive/My Drive/yolo/ultralytics/ultralytics

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
from ultralytics import YOLO
model = YOLO("yolov8x.pt")
# Out:
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 160MB/s]

# %%
results = model("https://ultralytics.com/images/bus.jpg",save=True)
# Out:
# ...
# 100%|██████████| 476k/476k [00:00<00:00, 7.97MB/s]
# image 1/1 /content/drive/MyDrive/yolo/ultralytics/ultralytics/bus.jpg: 640x480 5 persons, 1 bicycle, 1 bus, 4212.8ms
# Speed: 8.6ms preprocess, 4212.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/drive/MyDrive/yolo/ultralytics/runs/detect/predict2

# %%
results = model('/content/drive/MyDrive/yolo/dog.jpeg',save=True)
# Out:
# image 1/1 /content/drive/MyDrive/yolo/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 3755.3ms
# Speed: 2.6ms preprocess, 3755.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to /content/drive/MyDrive/yolo/ultralytics/runs/detect/predict2
